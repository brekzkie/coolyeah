# %% [markdown]
# ## Basic Data Grouping

# %%
import pandas as pd

# %%
# Load the data into a DataFrame
data = pd.read_csv('endangeredLang.csv')
 
data.head(6)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
# 5   405          Romani  Albania, Germany, Austria, Belarus, Bosnia and...
#
#                                Country codes alpha 3 Degree of endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# ...

# %%
 #sort in descending order by 'Number of speakers' and show 10 first row 
descending = data.sort_values('Number of speakers',ascending=False)
descending.head(10)
# Out:
#      ID              Name in English  \
# 0  1022                South Italian
# 1  1023                     Sicilian
# 2   383                    Low Saxon
# 3   335                   Belarusian
# 4   382                      Lombard
# 5   405                       Romani
# 6  2211             Yiddish (Israel)
# 7  1586                        Gondi
# 8  1020         Limburgian-Ripuarian
# 9  1943  Quechua of Southern Bolivia
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# ...

# %%
#sort in ascending order by 'Number of speakers' and show 10 first row 
ascending = data.sort_values('Number of speakers',ascending = True)
ascending.head(10)
# Out:
#         ID                           Name in English  \
# 2538   130                                    ǁXegwi
# 2374   477                                     Kamas
# 2373   696                    Judeo-Berber (Morocco)
# 2372  1925                                      Jorá
# 2371   857                            Island Chumash
# 2370   298                              Island Carib
# 2369   854                                   Ineseño
# 2368  2642                                       Ifo
# 2367  1537  Huron-Wyandot (United States of America)
# 2366  2592                                  Hukumina
#
#                              Countries Country codes alpha 3  \
# 2538                      South Africa                   ZAF
# 2374                Russian Federation                   RUS
# 2373                           Morocco                   MAR
# 2372  Bolivia (Plurinational State of)                   BOL
# 2371          United States of America                   USA
# ...

# %%
# Group by 'Degree of endangerment' and show 10 first row 
data.groupby(['Degree of endangerment']).count()
# Out:
#                          ID  Name in English  Countries  \
# Degree of endangerment
# Critically endangered   607              607        607
# Definitely endangered   680              680        679
# Extinct                 253              253        253
# Severely endangered     554              554        554
# Vulnerable              628              628        628
#
#                         Country codes alpha 3  Number of speakers  Latitude  \
# Degree of endangerment
# Critically endangered                     607                 544       606
# Definitely endangered                     679                 635       680
# Extinct                                   253                 244       252
# Severely endangered                       554                 505       554
# Vulnerable                                628                 611       627
#
#                         Longitude  Description of the location
# Degree of endangerment
# ...

# %%
# How many entries in each group based on Degree of endangerment
data.groupby(['Degree of endangerment']).count()
# Out:
#                          ID  Name in English  Countries  \
# Degree of endangerment
# Critically endangered   607              607        607
# Definitely endangered   680              680        679
# Extinct                 253              253        253
# Severely endangered     554              554        554
# Vulnerable              628              628        628
#
#                         Country codes alpha 3  Number of speakers  Latitude  \
# Degree of endangerment
# Critically endangered                     607                 544       606
# Definitely endangered                     679                 635       680
# Extinct                                   253                 244       252
# Severely endangered                       554                 505       554
# Vulnerable                                628                 611       627
#
#                         Longitude  Description of the location
# Degree of endangerment
# ...

# %%
#group on basis of two qualitative columns 


# pd.set_option('display.max_rows', None)  
# Show first 10 rows

# %%
# How many entries in each group based on 'Countries' and 'Degree of endangerment'
data.groupby(['Countries','Degree of endangerment']).count()
# Out:
#                                                                            ID  \
# Countries                                          Degree of endangerment
# Afghanistan                                        Critically endangered    2
#                                                    Definitely endangered    5
#                                                    Severely endangered      4
#                                                    Vulnerable               1
# Albania, Algeria, Bosnia and Herzegovina, Bulga... Severely endangered      1
# ...                                                                        ..
# Viet Nam                                           Severely endangered      2
#                                                    Vulnerable               4
# Western Sahara                                     Critically endangered    1
# Yemen                                              Definitely endangered    1
# ...

# %%
#group number of speakers by group labels (row names) from countries, then show 10 first row
x = data['Number of speakers'].groupby(data['Countries'])
x.head(10)
# Out:
# 0       7500000.0
# 1       5000000.0
# 2       4800000.0
# 3       4000000.0
# 4       3500000.0
#           ...
# 2714          NaN
# 2716          NaN
# 2717          NaN
# 2720          NaN
# 2721          NaN
# Name: Number of speakers, Length: 954, dtype: float64

# %% [markdown]
# ### lambda functions
#
# #### identify which languages have fewer then 5k speakers

# %%
#create new column 'vfew' that identify which languages have fewer then 5k speakers
data['fvew'] = data['Number of speakers'].apply(lambda x : x<=5000)
data['fvew']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2717    False
# 2718    False
# 2719    False
# 2720    False
# 2721    False
# Name: fvew, Length: 2722, dtype: bool

# %%
#Show 6 first column
data['fvew'].head(6)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: fvew, dtype: bool

# %%
# Group by 'vfew' and store in a variable called 'group_by_5k'
group_by_5k = data.groupby('fvew')

# %%
# group_by_5k.size()
group_by_5k.size()
# Out:
# fvew
# False     879
# True     1843
# dtype: int64

# %%
# Group by 'vfew' and 'Countries' and store in a variable called 'group_by_5kC
group_by_5kc = data.groupby(['fvew','Countries'])

# %%
#Show the size of each group
print((group_by_5k.size()))
print((group_by_5kc.size()))
# Out:
# fvew
# False     879
# True     1843
# dtype: int64
# fvew   Countries
# False  Afghanistan                                                                                                                                                                                                                                                                                                                                                                                      2
#        Albania, Algeria, Bosnia and Herzegovina, Bulgaria, Croatia, Greece, The former Yugoslav Republic of Macedonia, Morocco, Romania, Turkey, Serbia                                                                                                                                                                                                                                                 1
# ...

# %%
#Find the unique values of 'Degree of endangerment' and the number of each group
data['Degree of endangerment'].value_counts()
# Out:
# Degree of endangerment
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: count, dtype: int64

# %% [markdown]
# ## Subsetting and Indexing

# %%
#select all entries from index 2 onwards
data[2:]
# Out:
#         ID    Name in English  \
# 2      383          Low Saxon
# 3      335         Belarusian
# 4      382            Lombard
# 5      405             Romani
# 6     2211   Yiddish (Israel)
# ...    ...                ...
# 2717  1972           Yonaguni
# 2718  2018             Yucuna
# 2719  2015  Yurutí (Colombia)
# 2720  2716          Zangskari
# 2721  2177            Zidgali
#
#                                               Countries  \
# 2     Germany, Denmark, Netherlands, Poland, Russian...
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                    Italy, Switzerland
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                                Israel
# ...                                                 ...
# 2717                                              Japan
# 2718                                           Colombia
# 2719                                           Colombia
# ...

# %%
#select entries at even index location
data.iloc[1::2]
# Out:
#         ID              Name in English  \
# 1     1023                     Sicilian
# 3      335                   Belarusian
# 5      405                       Romani
# 7     1586                        Gondi
# 9     1943  Quechua of Southern Bolivia
# ...    ...                          ...
# 2713  2093                        Wichi
# 2715  1365                   Yazva Komi
# 2717  1972                     Yonaguni
# 2719  2015            Yurutí (Colombia)
# 2721  2177                      Zidgali
#
#                                               Countries  \
# 1                                                 Italy
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 5     Albania, Germany, Austria, Belarus, Bosnia and...
# 7                                                 India
# 9                      Bolivia (Plurinational State of)
# ...                                                 ...
# 2713        Argentina, Bolivia (Plurinational State of)
# ...

# %%
#specify the ranges of rows and columns --> first 8 rows and first 7 columns
#positional indexing
data.iloc[:7,:8]
# Out:
#      ID   Name in English                                          Countries  \
# 0  1022     South Italian                                              Italy
# 1  1023          Sicilian                                              Italy
# 2   383         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382           Lombard                                 Italy, Switzerland
# 5   405            Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 6  2211  Yiddish (Israel)                                             Israel
#
#                                Country codes alpha 3 Degree of endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# 2                            DEU, DNK, NLD, POL, RUS             Vulnerable
# ...

# %%
#select all columns for rows of index values 0 and 10
data.iloc[1:10]
# Out:
#      ID              Name in English  \
# 1  1023                     Sicilian
# 2   383                    Low Saxon
# 3   335                   Belarusian
# 4   382                      Lombard
# 5   405                       Romani
# 6  2211             Yiddish (Israel)
# 7  1586                        Gondi
# 8  1020         Limburgian-Ripuarian
# 9  1943  Quechua of Southern Bolivia
#
#                                            Countries  \
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# 9                   Bolivia (Plurinational State of)
#
# ...

# %%
#isolate rows and columns: Subset the data by only using column 'Countries' &'Name in English' 
#Only rows 4 - 7
data[['Countries','Name in English']].iloc[4:8]
# Out:
#                                            Countries   Name in English
# 4                                 Italy, Switzerland           Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...            Romani
# 6                                             Israel  Yiddish (Israel)
# 7                                              India             Gondi

# %%
#isolate by row names
#Select the data only from Italy 
data[data['Countries']=='Italy']
# Out:
#         ID    Name in English Countries Country codes alpha 3  \
# 0     1022      South Italian     Italy                   ITA
# 1     1023           Sicilian     Italy                   ITA
# 13     399        Piedmontese     Italy                   ITA
# 36     337        Campidanese     Italy                   ITA
# 53     353           Friulian     Italy                   ITA
# 80     381         Logudorese     Italy                   ITA
# 157    408          Sassarese     Italy                   ITA
# 170    356          Gallurese     Italy                   ITA
# 197   1347           Arbëresh     Italy                   ITA
# 212   1330     Gallo-Sicilian     Italy                   ITA
# 320    565              Ladin     Italy                   ITA
# 391   1614    Griko (Salento)     Italy                   ITA
# 510   1343  Algherese Catalan     Italy                   ITA
# 729   1349    Molise Croatian     Italy                   ITA
# ...

# %%
 #isolate by two row labels: Countries from Italy and Germany
x = data[data['Countries'].isin(['Italy','Germany'])]
x.head(15)
# Out:
#        ID    Name in English Countries Country codes alpha 3  \
# 0    1022      South Italian     Italy                   ITA
# 1    1023           Sicilian     Italy                   ITA
# 13    399        Piedmontese     Italy                   ITA
# 36    337        Campidanese     Italy                   ITA
# 53    353           Friulian     Italy                   ITA
# 80    381         Logudorese     Italy                   ITA
# 157   408          Sassarese     Italy                   ITA
# 170   356          Gallurese     Italy                   ITA
# 197  1347           Arbëresh     Italy                   ITA
# 212  1330     Gallo-Sicilian     Italy                   ITA
# 320   565              Ladin     Italy                   ITA
# 391  1614    Griko (Salento)     Italy                   ITA
# 406   384            Sorbian   Germany                   DEU
# 510  1343  Algherese Catalan     Italy                   ITA
# ...

# %%
# Isolate data from India with Degree of endangerment Vulnerable 
data[(data['Countries'] == "India") & (data['Degree of endangerment'] == "Vulnerable")]
# Out:
#         ID Name in English Countries Country codes alpha 3  \
# 7     1586           Gondi     India                   IND
# 16    1591   Kurux (India)     India                   IND
# 18    1585            Tulu     India                   IND
# 26    1227         Meithei     India                   IND
# 33    1577             Kui     India                   IND
# ...    ...             ...       ...                   ...
# 417   1142         Pochuri     India                   IND
# 467   1168         Khampti     India                   IND
# 594   1182          Rongpo     India                   IND
# 867   1096      Sherdukpen     India                   IND
# 2653  1566           Padri     India                   IND
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 7                Vulnerable           2713790.0   19.5804    80.4418
# 16               Vulnerable           1751489.0   22.1467    85.2758
# ...

# %%
#make a copy of the data frame stored in data
dataframe = data.copy()

# %%
#replace column name: "Number of Speakers" with "Number"
dataframe = dataframe.rename(columns={"Number of Speakers": "Number"})

# %%
#Isolate only data from India that <100 number of speakers
dataframe[dataframe['Number of speakers'] < 100]
# Out:
#         ID   Name in English         Countries Country codes alpha 3  \
# 1809  2104          Yarawata  Papua New Guinea                   PNG
# 1810  1480  O'odham (Mexico)            Mexico                   MEX
# 1811  2124            Samosa  Papua New Guinea                   PNG
# 1812  2116           Mindiri  Papua New Guinea                   PNG
# 1813  2130               Usu  Papua New Guinea                   PNG
# ...    ...               ...               ...                   ...
# 2534   131            |'Auni      South Africa                   ZAF
# 2535   136              |Xam      South Africa                   ZAF
# 2536  1443           ǁKu ǁ'e      South Africa                   ZAF
# 2537  1445            ǁKx'au      South Africa                   ZAF
# 2538   130            ǁXegwi      South Africa                   ZAF
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# ...

# %% [markdown]
# #### National Footprint Accounts 2018
#
# The Ecological Footprint of 196 Countries
#
# ##### National Footprint Accounts 2018
# The National Footprint Accounts (NFA) are an annual production from Global Footprint Network (www.footprintnetwork.org). Each year, we combine and synthesize over 30 datasets to calculate the Ecological Footprint and biocapacity of countries across the world in over 50 years.
#
# The goal of this undertaking is to produce accounts of how much area is required to provide the ecological services (resource regeneration and waste assimilation) consumed by humanity ("Ecological Footprint"), and how much biologically productive area exists to provide these ecological services ("biocapacity") in each year. With both values in hand, we can assess the overall sustainability of countries around the world and better understand the collective need for humanity to reduce its impact on nature.
#
# This data underpins both our Overshoot Day campaign and our Personal Footprint Calculator, both of which you should check out! All of our data is also available on our Data Platform.
#
# ##### Inspiration
# At Global Footprint Network we spend a lot of time calculating Ecological Footprint, and not as much time investigating and researching the trends we see. We are looking for cool stories, trends, interpretations, or visualizations that are meaningful to you or that you think would be meaningful to others. What is your country's footprint and biocapacity - and which is larger? Can you find out why? What about different regions or economic groups?
#
# Besides descriptive analytics, we are also driven to understand more about the causality of footprint values. Can you identify the effect of sustainable (or unsustainable) policies? Is there a good way to predict future values of footprint? Are there any external indicators closely tied to values of footprint?
#
# There are many ways to slice the data, and we hope you have fun finding your own approach!
#
# Splash Photo by Alexey Topolyanskiy on Unsplash

# %%
import numpy as np
import pandas as pd
import math

# %%
# Read "NFA 2018.csv"
df = pd.read_csv("NFA 2018.csv")
df
# Out:
#           country ISO alpha-3 code UN_region    UN_subregion  year  \
# 0         Armenia              ARM      Asia    Western Asia  1992
# 1         Armenia              ARM      Asia    Western Asia  1992
# 2         Armenia              ARM      Asia    Western Asia  1992
# 3         Armenia              ARM      Asia    Western Asia  1992
# 4         Armenia              ARM      Asia    Western Asia  1992
# ...           ...              ...       ...             ...   ...
# 87015  Luxembourg              LUX    Europe  Western Europe  1999
# 87016  Luxembourg              LUX    Europe  Western Europe  1999
# 87017  Luxembourg              LUX    Europe  Western Europe  1999
# 87018  Luxembourg              LUX    Europe  Western Europe  1999
# 87019  Luxembourg              LUX    Europe  Western Europe  1999
#
#                 record     crop_land   grazing_land    forest_land  \
# 0         BiocapPerCap  1.611286e-01       0.135023       0.083836
# ...

# %%
# Show 6 first rows
df.head(6)
# Out:
#    country ISO alpha-3 code UN_region  UN_subregion  year           record  \
# 0  Armenia              ARM      Asia  Western Asia  1992     BiocapPerCap
# 1  Armenia              ARM      Asia  Western Asia  1992     BiocapTotGHA
# 2  Armenia              ARM      Asia  Western Asia  1992     EFConsPerCap
# 3  Armenia              ARM      Asia  Western Asia  1992     EFConsTotGHA
# 4  Armenia              ARM      Asia  Western Asia  1992  EFExportsPerCap
# 5  Armenia              ARM      Asia  Western Asia  1992  EFExportsTotGHA
#
#       crop_land   grazing_land    forest_land  fishing_ground  built_up_land  \
# 0  1.611286e-01       0.135023       0.083836        0.013718       0.033669
# 1  5.558130e+05  465763.337400  289190.662300    47320.224590  116139.598200
# 2  3.909225e-01       0.189137       0.000001        0.004138       0.033669
# 3  1.348487e+06  652429.066600       4.327841    14272.803690  116139.598200
# ...

# %%
## list all unique categorical values in a column
df['record'].unique()
# Out:
# array(['BiocapPerCap', 'BiocapTotGHA', 'EFConsPerCap', 'EFConsTotGHA',
#        'EFExportsPerCap', 'EFExportsTotGHA', 'EFImportsPerCap',
#        'EFImportsTotGHA', 'EFProdPerCap', 'EFProdTotGHA'], dtype=object)

# %% [markdown]
# ### subset based on row values

# %%
# Now select data only from 'South-Eastern Asia'
df[df['UN_subregion'] == 'South-Eastern Asia']
# Out:
#                  country ISO alpha-3 code UN_region        UN_subregion  year  \
# 8900   Brunei Darussalam              BRN      Asia  South-Eastern Asia  1981
# 8901   Brunei Darussalam              BRN      Asia  South-Eastern Asia  1981
# 8902   Brunei Darussalam              BRN      Asia  South-Eastern Asia  1981
# 8903   Brunei Darussalam              BRN      Asia  South-Eastern Asia  1981
# 8904   Brunei Darussalam              BRN      Asia  South-Eastern Asia  1981
# ...                  ...              ...       ...                 ...   ...
# 81935           Viet Nam              VNM      Asia  South-Eastern Asia  2014
# 81936           Viet Nam              VNM      Asia  South-Eastern Asia  2014
# 81937           Viet Nam              VNM      Asia  South-Eastern Asia  2014
# 81938           Viet Nam              VNM      Asia  South-Eastern Asia  2014
# 81939           Viet Nam              VNM      Asia  South-Eastern Asia  2014
#
# ...

# %% [markdown]
# ### subset on basis of row numerical values

# %%
## isolate forest area>=5
df[df['forest_land'] >= 5]
# Out:
#           country ISO alpha-3 code UN_region    UN_subregion  year  \
# 1         Armenia              ARM      Asia    Western Asia  1992
# 11        Armenia              ARM      Asia    Western Asia  1993
# 13        Armenia              ARM      Asia    Western Asia  1993
# 17        Armenia              ARM      Asia    Western Asia  1993
# 21        Armenia              ARM      Asia    Western Asia  1994
# ...           ...              ...       ...             ...   ...
# 87011  Luxembourg              LUX    Europe  Western Europe  1999
# 87013  Luxembourg              LUX    Europe  Western Europe  1999
# 87015  Luxembourg              LUX    Europe  Western Europe  1999
# 87017  Luxembourg              LUX    Europe  Western Europe  1999
# 87019  Luxembourg              LUX    Europe  Western Europe  1999
#
#                 record     crop_land  grazing_land    forest_land  \
# 1         BiocapTotGHA  5.558130e+05  465763.33740  289190.662300
# ...

# %% [markdown]
# ### subset based on list

# %%
years = [1990, 2000, 2005] ## list of years

# %%
# check whether dataset is in the list of 'years'
seac_y= df[df['year'].isin(years)]

# %%
# seac_y.head()
seac_y.head()
# Out:
#     country ISO alpha-3 code UN_region  UN_subregion  year           record  \
# 80  Armenia              ARM      Asia  Western Asia  2000     BiocapPerCap
# 81  Armenia              ARM      Asia  Western Asia  2000     BiocapTotGHA
# 82  Armenia              ARM      Asia  Western Asia  2000     EFConsPerCap
# 83  Armenia              ARM      Asia  Western Asia  2000     EFConsTotGHA
# 84  Armenia              ARM      Asia  Western Asia  2000  EFExportsPerCap
#
#        crop_land   grazing_land    forest_land  fishing_ground  built_up_land  \
# 80  1.604935e-01       0.183081       0.093794        0.015304       0.029599
# 81  4.936942e+05  563176.839200  288520.910300    47075.673790   91050.151640
# 82  4.095542e-01       0.199877       0.014420        0.008785       0.029599
# 83  1.259830e+06  614842.264100   44356.729720    27022.891050   91050.151640
# 84  3.015902e-03       0.004984       0.000896        0.000223       0.000000
#
# ...

# %%
import pandas as pd

# %%
e = pd.read_csv('ebola.csv')
e.head()
# Out:
#                                            Indicator Country        Date  \
# 0  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
# 1         Cumulative number of confirmed Ebola cases  Guinea  2015-03-10
# 2          Cumulative number of probable Ebola cases  Guinea  2015-03-10
# 3         Cumulative number of suspected Ebola cases  Guinea  2015-03-10
# 4  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
#
#     value
# 0  3285.0
# 1  2871.0
# 2   392.0
# 3    22.0
# 4  2170.0

# %%
e.dtypes
# Out:
# Indicator     object
# Country       object
# Date          object
# value        float64
# dtype: object

# %% [markdown]
# ### Improve the readability of indicators

# %%
import re

# %%
def covertIndicators(ind):
    result = 'Unknown : Unknown'
    lst_ind = [
        { 'regx': r'Case fatality rate \(CFR\) of (.*) Ebola cases', 'abbv': 'CFR'},
        { 'regx': r'Cumulative number of (.*) Ebola deaths', 'abbv': 'Cumulative Deaths'},
        { 'regx': r'Cumulative number of (.*) Ebola cases', 'abbv': 'Cumulative Cases'},
        { 'regx': r'Proportion of (.*) Ebola deaths that are from the last 21 days', 'abbv': 'Proportion Deaths 21'},
        { 'regx': r'Proportion of (.*) Ebola cases that are from the last 21 days', 'abbv': 'Proportion Cases 21'},
        { 'regx': r'Proportion of (.*) Ebola cases that are from the last 7 days', 'abbv': 'Proportion Cases 07'},
        { 'regx': r'Number of (.*) Ebola deaths in the last 21 days', 'abbv': 'Number Deaths 21'},
        { 'regx': r'Number of (.*) Ebola cases in the last 21 days', 'abbv': 'Number Cases 21'},
        { 'regx': r'Number of (.*) Ebola cases in the last 7 days', 'abbv': 'Number Cases 07'},
    ]
    for i in lst_ind:
        match = re.search(i['regx'], ind)
        if match:
            tmp = str(match.group(1))
            result = i['abbv'] + ' : ' + (tmp if len(tmp) < 20 else 'All')
            break
    return result

# %%
# Convert all Indicators using function above

# %%
# Add new columns which consist of class indicator and sub indicator which consist of the last words of indicators

# %%
# e.drop(['Indicator', 'ind'], axis=1, inplace=True)
# e.head()

# %%
# e['ind_class'].unique()

# %% [markdown]
# ## Rank & Sorting

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series(range(4),index=['d','a','b','c'])

# %%
s
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
s.sort_index() #sort index from a to d
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
# Load GlobalFirePower.csv

# %%
 #index according to columns. Coulmns will be arranged alphabetically
#default ascending

# %%
#Show first 4 rows

# %%
 #index according to columns. Coulmns will be arranged Z-A
#descending

# %%
#Show first 4 rows

# %%
#Sort by ISO3

# %%
#Show first 4 rows

# %%
#sort by descending rank order

# %%
#Show first 4 rows

# %%
#Sort by ISO3 and Country

# %%
#Show first 4 rows

# %% [markdown]
# ### rank

# %%
# x=data.rank(axis=1) #Rank data column wise
x = data.select_dtypes(include=[np.number]).rank(axis=1)
#ascending

# %%
#Show first 4 rows

# %%
x=data.iloc[0:8,0:8]

# %%
data.head(4)

# %%
#Add new columns 'mRank', which calculate the rank of 'Fit-for-Service' in ascending level

# %%
#Show first 6 rows

# %% [markdown]
# ## concatenate

# %%
import pandas as pd
import numpy as np
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.12.3' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df1 = pd.DataFrame([['a', 1], ['b', 2]],
                  columns=['letter', 'number'])

df1
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.12.3' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df2 = pd.DataFrame([['c', 3], ['d', 4]],
                   columns=['letter', 'number'])
df2
# Out:
#   letter  number
# 0      c       3
# 1      d       4

# %%
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                    columns=['letter', 'number', 'animal'])
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
 #stitch the data together, one on top of the other

# %%
#only columns common for both data frames are joined togther

# %%
drink = pd.read_csv('starbucks-menu-nutrition-drinks.csv')
 
drink.head(5)
# Out:
#                                           Unnamed: 0 Calories Fat (g)  \
# 0           Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                   Ombré Pink Drink        -       -
# 2                                         Pink Drink        -       -
# 3     Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4  Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
#
#   Carb. (g) Fiber (g) Protein Sodium
# 0        11         0       0     10
# 1         -         -       -      -
# 2         -         -       -      -
# 3        18         1       0     10
# 4        14         1       0     10

# %%
import pandas as pd
import numpy as np

# %%
food = pd.read_csv('starbucks-menu-nutrition-food.csv', encoding='utf-16')
food.head(5)
# Out:
#          Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0      Chonga Bagel        300       5.0          50           3            12
# 1      8-Grain Roll        380       6.0          70           7            10
# 2  Almond Croissant        410      22.0          45           3            10
# 3     Apple Fritter        460      23.0          56           2             7
# 4  Banana Nut Bread        420      22.0          52           2             6

# %%
drink = pd.read_csv("starbucks-menu-nutrition-drinks.csv")
drink
# Out:
#                                             Unnamed: 0 Calories Fat (g)  \
# 0             Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                     Ombré Pink Drink        -       -
# 2                                           Pink Drink        -       -
# 3       Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
# ..                                                 ...      ...     ...
# 172                                 Chocolate Smoothie      320       5
# 173                                Strawberry Smoothie      300       2
# 174                                         Ginger Ale        -       -
# 175                                          Lemon Ale        -       -
# 176                                  Orange Cream Soda        -       -
#
#     Carb. (g) Fiber (g) Protein Sodium
# 0          11         0       0     10
# ...

# %%
#Concat the drink and food 
starbucks = pd.concat((food,drink))
starbucks
# Out:
#               Unnamed: 0   Calories   Fat (g)   Carb. (g)   Fiber (g)  \
# 0           Chonga Bagel      300.0       5.0        50.0         3.0
# 1           8-Grain Roll      380.0       6.0        70.0         7.0
# 2       Almond Croissant      410.0      22.0        45.0         3.0
# 3          Apple Fritter      460.0      23.0        56.0         2.0
# 4       Banana Nut Bread      420.0      22.0        52.0         2.0
# ..                   ...        ...       ...         ...         ...
# 172   Chocolate Smoothie        NaN       NaN         NaN         NaN
# 173  Strawberry Smoothie        NaN       NaN         NaN         NaN
# 174           Ginger Ale        NaN       NaN         NaN         NaN
# 175            Lemon Ale        NaN       NaN         NaN         NaN
# 176    Orange Cream Soda        NaN       NaN         NaN         NaN
#
#       Protein (g) Calories Fat (g) Carb. (g) Fiber (g) Protein Sodium
# ...

# %%
df = pd.DataFrame(starbucks)

# %%
# only concatenate the common columns
starbucksnew = pd.concat((food,drink),join = "inner")
starbucksnew
# Out:
#               Unnamed: 0
# 0           Chonga Bagel
# 1           8-Grain Roll
# 2       Almond Croissant
# 3          Apple Fritter
# 4       Banana Nut Bread
# ..                   ...
# 172   Chocolate Smoothie
# 173  Strawberry Smoothie
# 174           Ginger Ale
# 175            Lemon Ale
# 176    Orange Cream Soda
#
# [290 rows x 1 columns]

# %%
#Chech the data shape
starbucks.shape
# Out:
# (290, 12)

# %%
# rename the food column ['Item','Calories','Fat','Carb','Fiber','Protein']
starbucks_columns = ['Item', 'Calories', 'Fat', 'Carb', 'Fiber', 'Protein']

# %%
food.rename(columns={
    'Unnamed: 0': 'Item',
    'Calories': 'Calories',
    'Fat (g)': 'Fat',
    'Carb. (g)': 'Carb',
    'Fiber (g)': 'Fiber',
    'Protein (g)': 'Protein'
}, inplace=True)

# %%
# Check first 4 rows
food.head(4)
# Out:
#                Item   Calories   Fat (g)   Carb. (g)   Fiber (g)   Protein (g)
# 0      Chonga Bagel        300       5.0          50           3            12
# 1      8-Grain Roll        380       6.0          70           7            10
# 2  Almond Croissant        410      22.0          45           3            10
# 3     Apple Fritter        460      23.0          56           2             7

# %%
drink
# Out:
#                                             Unnamed: 0 Calories Fat (g)  \
# 0             Cool Lime Starbucks Refreshers™ Beverage       45       0
# 1                                     Ombré Pink Drink        -       -
# 2                                           Pink Drink        -       -
# 3       Strawberry Acai Starbucks Refreshers™ Beverage       80       0
# 4    Very Berry Hibiscus Starbucks Refreshers™ Beve...       60       0
# ..                                                 ...      ...     ...
# 172                                 Chocolate Smoothie      320       5
# 173                                Strawberry Smoothie      300       2
# 174                                         Ginger Ale        -       -
# 175                                          Lemon Ale        -       -
# 176                                  Orange Cream Soda        -       -
#
#     Carb. (g) Fiber (g) Protein Sodium
# 0          11         0       0     10
# ...

# %%
# rename the food column ['Item','Calories','Fat','Carb','Fiber','Protein','Na']
drink.rename(columns={
    'Unnamed: 0': 'Item',
    'Calories': 'Calories',
    'Fat (g)': 'Fat',
    'Carb. (g)': 'Carb',
    'Fiber (g)': 'Fiber',
    'Protein (g)': 'Protein',
    'Sodium':'Na'
}, inplace=True)

# %%
# Check first 4 rows
drink.head(4)
# Out:
#                                              Item Calories Fat Carb Fiber  \
# 0        Cool Lime Starbucks Refreshers™ Beverage       45   0   11     0
# 1                                Ombré Pink Drink        -   -    -     -
# 2                                      Pink Drink        -   -    -     -
# 3  Strawberry Acai Starbucks Refreshers™ Beverage       80   0   18     1
#
#   Protein  Na
# 0       0  10
# 1       -   -
# 2       -   -
# 3       0  10

# %%
# concatenates all common columns
df = pd.concat((food,drink),join='inner')
df
# Out:
#                     Item
# 0           Chonga Bagel
# 1           8-Grain Roll
# 2       Almond Croissant
# 3          Apple Fritter
# 4       Banana Nut Bread
# ..                   ...
# 172   Chocolate Smoothie
# 173  Strawberry Smoothie
# 174           Ginger Ale
# 175            Lemon Ale
# 176    Orange Cream Soda
#
# [290 rows x 1 columns]

# %%
 #concatenates all columns
dfnew = pd.concat((food,drink))
dfnew.head(4)
# Out:
#                Item   Calories   Fat (g)   Carb. (g)   Fiber (g)  \
# 0      Chonga Bagel      300.0       5.0        50.0         3.0
# 1      8-Grain Roll      380.0       6.0        70.0         7.0
# 2  Almond Croissant      410.0      22.0        45.0         3.0
# 3     Apple Fritter      460.0      23.0        56.0         2.0
#
#     Protein (g) Calories  Fat Carb Fiber Protein   Na
# 0          12.0      NaN  NaN  NaN   NaN     NaN  NaN
# 1          10.0      NaN  NaN  NaN   NaN     NaN  NaN
# 2          10.0      NaN  NaN  NaN   NaN     NaN  NaN
# 3           7.0      NaN  NaN  NaN   NaN     NaN  NaN

# %% [markdown]
# ### **MERGE**

# %%
# Read 'countryGDP.csv' data
country = pd.read_csv("countryGDP.csv")

# %%
# Check first 4 rows
country.head(4)
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN

# %%
# show the shape of dataset
country.shape
# Out:
# (201, 4)

# %%
# Now read 'GlobalFirePower.csv' data
globalfire = pd.read_csv('GlobalFirePower.csv')

# %%
# Check first 4 rows
globalfire.head(4)
# Out:
#          Country ISO3  Rank  Total Population  Manpower Available  \
# 0  United States  USA     1         323995528           145215000
# 1         Russia  RUS     2         142355415            70000000
# 2          China  CHN     3        1373541278           750000000
# 3          India  IND     4        1266883598           616000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250
#
#    Active Personnel  Reserve Personnel  ...  Railway Coverage (km)  \
# 0           1373650             990025  ...                 224792
# 1            798527            2572500  ...                  87157
# 2           2260000            1452500  ...                  86000
# ...

# %%
# merge on column that have common entries
# default "inner" value
df = pd.concat((globalfire,country),join = 'inner')

# %%
# Check first 6 rows
df.head(6)
# Out:
#           Country
# 0   United States
# 1          Russia
# 2           China
# 3           India
# 4          France
# 5  United Kingdom

# %%
#merge only a few columns (Manpower available and Railway overage) with the GDP data frame using the Country Column
y = pd.merge(country,globalfire [['Country','Manpower Available','Railway Coverage (km)']],on = 'Country',how ='outer',indicator = True)

# %%
# Check first 6 rows
y.head(6)
# Out:
#            Country Code  Population  GDP per Capita  Manpower Available  \
# 0      Afghanistan  AFG  32526562.0      594.323081          14000000.0
# 1          Albania  ALB   2889167.0     3945.217582           1515000.0
# 2          Algeria  ALG  39666519.0     4206.031232          20400000.0
# 3  American Samoa*  ASA     55538.0             NaN                 NaN
# 4          Andorra  AND     70473.0             NaN                 NaN
# 5           Angola  ANG  25021974.0     4101.472152           6030000.0
#
#    Railway Coverage (km)     _merge
# 0                    0.0       both
# 1                  339.0       both
# 2                 3973.0       both
# 3                    NaN  left_only
# 4                    NaN  left_only
# 5                 2764.0       both

# %%
#Show the shape of data

# %%
#why 126?

# %%
# gfp['Country'].isin(gdp['Country']).value_counts() #126 values of gdp appear in gfp too

# %%
#Database type merging

# %%
#Keep every row in the left dataframe. Where there are missing values of the "on" variable in the right dataframe, add empty

# %%
# Check first 7 rows

# %%
# Check the shape of dataset
# Out:
# (201, 6)

# %%
#Keep every row in the right dataframe. Where there are missing values of the "on" variable in the right dataframe, add empty

# %%
# Check last 7 rows

# %%
#A full outer join returns all the rows from the left dataframe, 
#all the rows from the right dataframe, and matches up rows where possible, with NaNs elsewhere
#indicator will tell us the joining was done

# %%
#Show the shape of data
# Out:
# (208, 7)

# %%
# Check first 10 rows

# %% [markdown]
# ### comparing the differences between string sequences

# %%
# !pip install fuzzywuzzy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Read room_type.csv and show first 10 rows
room = pd.read_csv('room_type.csv')
room.head(10)
# Out:
#                                      Expedia  \
# 0                    Deluxe Room, 1 King Bed
# 1      Standard Room, 1 King Bed, Accessible
# 2         Grand Corner King Room, 1 King Bed
# 3                 Suite, 1 King Bed (Parlor)
# 4        High-Floor Premium Room, 1 King Bed
# 5     Traditional Double Room, 2 Double Beds
# 6               Room, 1 King Bed, Accessible
# 7                    Deluxe Room, 1 King Bed
# 8                                Deluxe Room
# 9  Room, 2 Double Beds (19th to 25th Floors)
#
#                                          Booking.com
# 0                                   Deluxe King Room
# 1            Standard King Roll-in Shower Accessible
# 2                             Grand Corner King Room
# 3                                  King Parlor Suite
# 4                       High-Floor Premium King Room
# 5                   Double Room with Two Double Beds
# 6                      King Room - Disability Access
# ...

# %%
from fuzzywuzzy import fuzz
## pip install fuzzywuzzy

# %%
# Check the fuzzy ration between 'Grand Corner King Room, 1 King Bed' and 'Grand Corner King Room'
# Out:
# 79

# %%
## sensitive to minor differences in word order

# %%
# Check the partial ration of 'Grand Corner King Room, 1 King Bed' and 'Grand Corner King Room'
# Out:
# 100

# %% [markdown]
# #### ignore word order

# %%
# Now lets ignore word order and find the token sort ration of 'Suite, 1 King Bed (Parlor)' and 'King Parlor Suite'
